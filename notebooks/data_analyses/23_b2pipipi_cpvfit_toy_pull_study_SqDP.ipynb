# %% [markdown]
# # $B^\pm \to \pi^\pm\pi^\pm\pi^\mp$ — estudo de pull sobre 500 toys do Laura++
#
# Este notebook reusa, sem alterações, o mesmo modelo isobárico CP de
# `22_b2pipipi_cpvfit_laura_comparison.ipynb` (mesmos mapas de eficiência ACC, histogramas de
# background `qqbar`/`kpipibkg`, yields fixos e assimetrias de yield) e o aplica a 500 amostras de
# toy-MC geradas pelo Laura++ em
#
# ```
# /home/juan-leite/Work/Laura-3.8.0/Laura++/bto3pi_toys_jussara/gen_pipipinotav3_16-9--16h2m23s/Gen3pi_test.root
# ```
#
# Cada experimento (toy) é selecionado pelo branch `iExpt` (`fitTree`), com valores inteiros de `0`
# a `499`. Após ajustar cada um dos 500 toys com exatamente a mesma configuração do notebook 22, os
# valores ajustados de cada parâmetro livre são histogramados e comparados com os valores
# verdadeiros de geração -- que são os mesmos `COEFFICIENT_SPECS`/`DYNAMICS_SPECS` já tabulados no
# notebook 22 (o Laura++ gera esses toys a partir do resultado final daquele ajuste).
#
# ## O que muda em relação ao notebook 22
#
# Só a amostra de dados. Caminhos de ACC/background, yields fixos (`N_SIGNAL`, `N_QQBAR`,
# `N_KPIPIBKG`) e as assimetrias de yield (`QQBAR_YIELD_ASYMMETRY`, `KPIPIBKG_YIELD_ASYMMETRY`)
# permanecem exatamente os mesmos -- eles descrevem o mapa de aceitância/composição do experimento
# real, não a amostra específica de `iExpt`. `plus_model`/`minus_model`, os mapas de
# eficiência/background e as formas de background com assimetria embutida (`qqbar_plus_shape` etc.)
# são construídos uma única vez e reaproveitados nos 500 ajustes; só `plus_data`/`minus_data` mudam
# a cada `iExpt`.
#
# ## Um artefato de geração descoberto ao rodar o primeiro toy
#
# Ao contrário dos dados reais do notebook 22, a NLL no ponto de partida de alguns toys é `inf`: um
# punhado de eventos (tipicamente 2-5 em ~95 mil, por carga) cai exatamente num bin de eficiência
# zero do mapa ACC interpolado (`SquareDalitzHistogramEfficiency(..., clip=True)`), o que dá
# densidade de sinal zero e portanto `-log(0) = inf` na verossimilhança estendida. Isso não ocorre
# nos dados reais (que já passaram pela eficiência do detector, então não populam regiões de
# eficiência nula), mas pode ocorrer no toy-MC do Laura++ perto das bordas/bins de borda do mapa de
# aceitação usado para a geração, por pequenas diferenças de convenção/interpolação entre o gerador
# e `SquareDalitzHistogramEfficiency`. A correção adotada aqui é descartar esses eventos de fronteira
# por toy (tipicamente < 0.01% da amostra) antes do ajuste -- ver a célula "Dados dos toys" abaixo.
#
# ## Sobre o tempo de execução
#
# Cada ajuste (43 parâmetros livres, HESSE via `hessian="jax"`, ~95 mil eventos por toy somando as
# duas cargas) leva ~70s nesta máquina; os 500 toys somam bem mais de 8 horas. O laço de ajuste abaixo
# salva o resultado de cada toy incrementalmente em `TOY_RESULTS_CSV` e pula `iExpt` já presentes
# nesse CSV, então a célula pode ser interrompida e retomada sem perder trabalho. `TOY_INDICES` pode
# ser reduzido (p.ex. `range(5)`) para um teste rápido antes de rodar os 500.

# %%
import os 

flags = os.environ.get("XLA_FLAGS", "")
os.environ["XLA_FLAGS"] = (
    flags + " --xla_cpu_multi_thread_eigen=true"
).strip()

os.environ["JAX_PLATFORMS"] = "cuda" # cpu, cuda, tpu
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false" 
# The sequential Hessian-vector implementation fits in JAX's standard BFC
# allocator on this 4 GiB GPU; keep the default allocator.
os.environ.pop("XLA_PYTHON_CLIENT_ALLOCATOR", None)

# %%
import sys
from pathlib import Path

for candidate in (Path.cwd(), *Path.cwd().parents):
    if (candidate / "src" / "dalitzplotfitter").is_dir():
        sys.path.insert(0, str(candidate / "src"))
        break

import time

import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from scipy.optimize import curve_fit

from dalitzplotfitter import (
    CompositeVeto,
    CPFitSession,
    CPRealImag,
    DecayChannel,
    DecayModel,
    GounarisSakurai,
    MassWindowVeto,
    Parameter,
    PhaseSpaceSample,
    SquareDalitzHistogramBackground,
    SquareDalitzHistogramEfficiency,
    RelativisticBreitWigner,
    Resonance,
    SigmaPole,
    ZemachP,
    enable_x64,
    read_root_histogram2d,
    read_root_tree,
)



enable_x64()

# %% [markdown]
# ## Configuração
#
# Caminhos e constantes idênticos a `22_b2pipipi_cpvfit_laura_comparison.ipynb`, exceto
# `TOY_FILE`/`TOY_TREE`, que apontam para os 500 toys em vez dos dados reais.

# %%
INPUTS = Path("/home/juan-leite/Work/data/fit415489_pipipinotav3_21-5--11h32m13s415489/inputs")

ACC_FILE = INPUTS / "ACC_pipipi_15161718_NoSpike_prodAsy.root"
ACC_HIST_PLUS = "Hacc_pipipi_15161718_Plus"
ACC_HIST_MINUS = "Hacc_pipipi_15161718_Minus"

QQBAR_BKG_FILE = INPUTS / "Lau_3pi_BKG_pm_322_V2h_splot_normcut.root"
QQBAR_HIST_PLUS = "hbkgbp"
QQBAR_HIST_MINUS = "hbkgbm"

KPIPI_BKG_FILE = INPUTS / "bkg_kpipi_histo.root"
KPIPI_HIST = "hbkg"  # same histogram used for both B+ and B- in the .cc

D0_VETO_MIN_GEV = 1.74
D0_VETO_MAX_GEV = 1.894

N_TOTAL_EVENTS = 95110.0
SIGNAL_FRACTION = 0.8845
QQBAR_FRACTION = 0.1155
N_SIGNAL = N_TOTAL_EVENTS * SIGNAL_FRACTION
N_QQBAR = N_TOTAL_EVENTS * QQBAR_FRACTION
QQBAR_YIELD_ASYMMETRY = -0.0078  # qqbarEventsAsym, fixed

N_KPIPIBKG = 0.  # nBgkpipiEvents = 95120*.0, fixed -- inert, kept only for structural fidelity
KPIPIBKG_YIELD_ASYMMETRY = 0.03  # kpipibkgEventsAsym, fixed -- inert since the yield above is 0

NORMALIZATION_CONFIG = {
    "normalization_method": "square-dalitz",
    "normalization_pair": (0,1),
    "normalization_chunk_size": 250_000,
    "normalization_resolution": 500,
    "normalization_binning_factor": 100,
    # The 250k grid fits one macroblock; 25k divides it without padding.
    # Measured 35% faster per warm value/gradient than 200k/100k on RTX 3050 Ti.
    "dynamics_microbatch_size": 25_000,
    "dynamics_microbatch_parallelism": 4,  # 1 for sequential Hessian-vector, 2 for parallel
}

# NORMALIZATION_CONFIG = {
#     "normalization_method": "gauss-legendre",
#     #"normalization_pair": (0, 1),
#     "normalization_chunk_size": 50_000,
#     #"normalization_resolution": 500,
#     "normalization_binning_factor": 100,
# }

# Toy-MC sample: 500 independent experiments, selected by the `iExpt` branch (0..499).
TOY_FILE = Path(
    "/home/juan-leite/Work/Laura-3.8.0/Laura++/bto3pi_toys_jussara/"
    "gen_pipipinotav3_16-9--16h2m23s/Gen3pi_test.root"
)
TOY_TREE = "fitTree"
N_EXPERIMENTS = 500
TOY_INDICES = range(N_EXPERIMENTS)  # narrow this (e.g. range(5)) for a quick smoke test

TOY_RESULTS_CSV = Path("23_b2pipipi_cpvfit_toy_pull_study__SQDP_results.csv")

print(f"N_signal = {N_SIGNAL:.3f}   N_qqbar = {N_QQBAR:.3f}   sum = {N_SIGNAL + N_QQBAR:.3f}")
# Out:
# N_signal = 84124.795   N_qqbar = 10985.205   sum = 95110.000

# %% [markdown]
# ## Canais e veto
#
# Idêntico ao notebook 22.

# %%
PLUS_CHANNEL = DecayChannel("B+", ("pi+", "pi+", "pi-"))
MINUS_CHANNEL = DecayChannel("B-", ("pi-", "pi-", "pi+"))

MOTHER_MASS = PLUS_CHANNEL.parent_mass
DAUGHTER_MASSES = PLUS_CHANNEL.daughter_masses
SQDP_PAIR = (0, 1)  # the two identical pi+/pi-, per the sibling Laura-toy benchmark notebook
RESONANCE_PAIR = (2, 0)  # resPairAmpInt=2 for every resonance in the .cc

print("mother mass [GeV] =", MOTHER_MASS)
print("daughter masses [GeV] =", DAUGHTER_MASSES)

D0_VETO = CompositeVeto(
    MassWindowVeto((0, 2), D0_VETO_MIN_GEV, D0_VETO_MAX_GEV),
    MassWindowVeto((1, 2), D0_VETO_MIN_GEV, D0_VETO_MAX_GEV),
)
# Out:
# mother mass [GeV] = 5.2794099999999995
# daughter masses [GeV] = (0.13957039000000002, 0.13957039000000002, 0.13957039000000002)

# %% [markdown]
# ## Dados dos toys
#
# `fitTree` no arquivo de toys tem os mesmos branches `m12Sq`/`m13Sq`/`m23Sq`/`charge` (mesma
# convenção de índices `(pi+, pi+, pi-)`) que o `fitTree` dos dados reais, mais `iExpt` (0..499,
# identifica o experimento/toy). Só o branch `iExpt` é lido inteiro (47.5 milhões de `int32`, ~190
# MB) para localizar, via `np.searchsorted`, o intervalo contíguo de entradas de cada toy -- os 500
# experimentos são gravados em blocos contíguos e não decrescentes por `iExpt`, verificado abaixo.
# `load_toy_samples(iexpt)` então relê do disco só o bloco daquele toy (`entry_start`/`entry_stop`),
# ~95 mil linhas de uma vez, em vez de manter as 47.5 milhões de linhas inteiras (5 branches) em
# memória durante todo o laço de 8 horas.
#
# `drop_zero_efficiency_events` descarta os poucos eventos por toy que caem num bin de eficiência
# zero do mapa ACC (ver a explicação no topo do notebook) -- sem isso a verossimilhança estendida
# diverge (`NLL = inf`) e o ajuste nunca sai do ponto de partida.

# %%
_RAW_IEXPT = np.asarray(
    read_root_tree(TOY_FILE, TOY_TREE, {"iExpt": "iExpt"}, library="np")["iExpt"]
)
print(f"toy file entries: {len(_RAW_IEXPT):,}   experiments: {_RAW_IEXPT.min()}..{_RAW_IEXPT.max()}")

# `iExpt` is written contiguously and non-decreasing (each of the 500 experiments is one
# contiguous run of rows), so `np.searchsorted` gives each toy's exact entry range from this
# single int32 branch alone. `load_toy_samples` then re-reads only that one toy's ~95k-row block
# per call (split into B+/B- in memory), instead of keeping the full 47.5-million-row tree
# resident in host memory for the whole 8-hour loop below.
_TOY_ENTRY_START = np.searchsorted(_RAW_IEXPT, np.arange(N_EXPERIMENTS), side="left")
_TOY_ENTRY_STOP = np.searchsorted(_RAW_IEXPT, np.arange(N_EXPERIMENTS), side="right")
del _RAW_IEXPT


def load_toy_samples(iexpt):
    """Read one toy's block from disk and split it into B+/B- ``PhaseSpaceSample``s."""
    block = read_root_tree(
        TOY_FILE, TOY_TREE,
        {"s12": "m12Sq", "s13": "m13Sq", "s23": "m23Sq", "charge": "charge"},
        entry_start=int(_TOY_ENTRY_START[iexpt]),
        entry_stop=int(_TOY_ENTRY_STOP[iexpt]),
        library="np",
    )
    charge = block["charge"]
    samples = {}
    for charge_value in (+1, -1):
        mask = charge == charge_value
        n = int(mask.sum())
        sample = PhaseSpaceSample(
            s12=jnp.asarray(block["s12"][mask]),
            s13=jnp.asarray(block["s13"][mask]),
            s23=jnp.asarray(block["s23"][mask]),
            weights=jnp.ones(n, dtype=jnp.float64),
        )
        samples[charge_value] = D0_VETO.apply(sample)
    return samples


def drop_zero_efficiency_events(sample, efficiency):
    values = np.asarray(efficiency(sample.as_dict()))
    keep = values > 0.0
    n_dropped = int((~keep).sum())
    if n_dropped == 0:
        return sample, 0
    filtered = PhaseSpaceSample(
        s12=sample.s12[keep], s13=sample.s13[keep], s23=sample.s23[keep],
        weights=sample.weights[keep],
    )
    return filtered, n_dropped


# sanity check on experiment 0, same as the fit loop will do for every iExpt
_probe = load_toy_samples(0)
print(f"iExpt=0: B+ events (post D0 veto) = {_probe[+1].size:,}   "
      f"B- events (post D0 veto) = {_probe[-1].size:,}")
del _probe
# Out:
# toy file entries: 47,560,440   experiments: 0..499
# iExpt=0: B+ events (post D0 veto) = 43,697   B- events (post D0 veto) = 51,382

# %% [markdown]
# ## Eficiência (ACC)
#
# Idêntico ao notebook 22 -- mesmo arquivo/histogramas, construído uma única vez e reaproveitado nos
# 500 toys.

# %%
def _load_square_dalitz_histogram2d(file_path, histogram):
    values, mp_edges, tp_edges = read_root_histogram2d(file_path, histogram)
    return jnp.asarray(values), jnp.asarray(mp_edges), jnp.asarray(tp_edges)


def _laura_efficiency(file_path, histogram):
    values, mp_edges, tp_edges = _load_square_dalitz_histogram2d(file_path, histogram)
    return SquareDalitzHistogramEfficiency(
        mprime_edges=mp_edges, thetaprime_edges=tp_edges, values=values,
        mother_mass=MOTHER_MASS, masses=DAUGHTER_MASSES, pair=SQDP_PAIR, folded=True, interpolation="spline", clip=True,
    )


plus_efficiency = _laura_efficiency(ACC_FILE, ACC_HIST_PLUS)
minus_efficiency = _laura_efficiency(ACC_FILE, ACC_HIST_MINUS)
print("ACC B+ grid:", plus_efficiency.values.shape, "  ACC B- grid:", minus_efficiency.values.shape)
# Out:
# ACC B+ grid: (30, 30)   ACC B- grid: (30, 30)

# %% [markdown]
# ## Background `qqbar` e `kpipibkg`
#
# Idêntico ao notebook 22 -- mesmos histogramas, mesma interpolação/jacobiano. A assimetria de yield
# fixa é aplicada mais abaixo, depois que `plus_model`/`minus_model` existem, exatamente como no
# notebook 22.

# %%
def _laura_background(file_path, histogram):
    values, mp_edges, tp_edges = _load_square_dalitz_histogram2d(file_path, histogram)
    return SquareDalitzHistogramBackground(
        mprime_edges=mp_edges, thetaprime_edges=tp_edges, values=values,
        mother_mass=MOTHER_MASS, masses=DAUGHTER_MASSES, pair=SQDP_PAIR, folded=True, interpolation="spline", divide_jacobian=True,
    )


_qqbar_plus_pdf = _laura_background(QQBAR_BKG_FILE, QQBAR_HIST_PLUS)
_qqbar_minus_pdf = _laura_background(QQBAR_BKG_FILE, QQBAR_HIST_MINUS)
_kpipibkg_pdf = _laura_background(KPIPI_BKG_FILE, KPIPI_HIST)

print("qqbar B+ grid:", _qqbar_plus_pdf.values.shape, "  qqbar B- grid:", _qqbar_minus_pdf.values.shape)
print("kpipibkg grid:", _kpipibkg_pdf.values.shape)
# Out:
# qqbar B+ grid: (60, 30)   qqbar B- grid: (60, 30)
# kpipibkg grid: (15, 15)

# %% [markdown]
# ## Coeficientes CP e parâmetros de massa/largura
#
# `COEFFICIENT_SPECS` é idêntico ao notebook 22: são os coeficientes CP *convergidos* do ajuste real
# (`LAURA_FINAL` na célula de comparação do notebook 22), que é também o valor verdadeiro de geração
# dos 500 toys.
#
# `DYNAMICS_SPECS`, por outro lado, **difere** do notebook 22: aqui as massas/larguras dos 5
# recursos que flutuam no ajuste real (`rho0_770`, `f2_1270`, `sigma0`, `f0_980`, `f0_1370`) usam os
# valores **convergidos** (`LAURA_FINAL`), não os valores de *partida* da tabela padrão
# `LauResonanceMaker.cc` que o notebook 22 usa como ponto de partida do seu próprio ajuste. Os toys
# foram gerados a partir do modelo convergido, então o valor de partida da tabela padrão **não** é o
# valor verdadeiro de geração -- usar aquele valor aqui foi a causa raiz de um bias sistemático grande
# nos coeficientes CP (maior em `sigma0`/`f0_1370`/`f0_980`, cujas larguras de partida e convergidas
# diferem 20-100%; desprezível em `rho0_3_1690`/`chi_c0`/`omega_782`/`rho0_770`, cuja dinâmica nunca
# flutuou no ajuste real).

# %%
# name: (x, y, dx, dy, fix_x, fix_y, fix_dx, fix_dy)
COEFFICIENT_SPECS = {
    "rho0_770":    (1.00000e+00,  0.00000e+00,  1.02312e-03,  0.00000e+00, True,  True,  False, True),
    "omega_782":   (-3.03268e-02, 9.48849e-02,  7.29877e-03,  1.38260e-02, False, False, False, False),
    "rho0_1450":   (-2.70865e-01, 1.13529e-01, -9.16491e-02, -7.71941e-03, False, False, False, False),
    "f2_1270":     (3.51291e-01,  1.71931e-01, -5.45892e-02, -1.17944e-01, False, False, False, False),
    "rho0_3_1690": (9.64994e-02,  1.91968e-02,  4.92371e-02,  5.41424e-02, False, False, False, False),
    "sigma0":      (-4.02003e-01, 3.57099e-01,  2.86690e-01,  2.01322e-01, False, False, False, False),
    "f0_980":      (1.41060e-01, -1.40500e-02, -4.50930e-02, -7.70899e-02, False, False, False, False),
    "chi_c0":      (2.71432e-02,  1.41733e-02, -4.02037e-02, -4.02666e-02, False, False, False, False),
    "f0_1370":     (1.00608e-01, -2.34739e-02,  5.11699e-02, -5.63136e-02, False, False, False, False),
}

# name: (mass, width, fixed, mass_bounds, width_bounds)
# DYNAMICS_SPECS = {
#     "rho0_770":    (0.77526, 0.14780, False, (0.60, 0.95), (0.05, 0.30)),
#     "omega_782":   (0.78265, 0.00849, True,  None, None),
#     "rho0_1450":   (1.46500, 0.40000, True,  None, None),
#     "f2_1270":     (1.27550, 0.18670, False, (1.10, 1.40), (0.05, 0.35)),
#     "rho0_3_1690": (1.68600, 0.18600, True,  None, None),
#     "sigma0":      (0.47500, 0.55000, False, (0.30, 0.70), (0.20, 0.90)),
#     "f0_980":      (0.99000, 0.07000, False, (0.85, 1.10), (0.01, 0.20)),
#     "chi_c0":      (3.41471, 0.01310, True,  None, None),
#     "f0_1370":     (1.37000, 0.35000, False, (1.10, 1.80), (0.05, 0.60)),
# }

# rho0_770/f2_1270/sigma0/f0_980/f0_1370 mass/width below are the Laura++ *converged* fit
# values (GenFit3piCP_fit_415489.log, same as LAURA_FINAL in notebook 22's cell 26) -- these
# toys were generated from that converged model, not from LauResonanceMaker's starting/default
# table. Using the starting-table values here (0.77526/0.1478 for rho0_770, 0.475/0.55 for
# sigma0, 1.37/0.35 for f0_1370, etc.) was the root cause of the large, systematic coefficient
# bias seen in the first 500-toy run: with dynamics fixed (fixed=True below), the coefficients
# had no way to absorb the mass/width mismatch between the (wrong) fixed value and the actual
# generation value, so the mismatch leaked entirely into the CP-coefficient pulls -- worst for
# sigma0/f0_1370/f0_980, whose starting-vs-converged width differs by 20-100%, and negligible
# for rho0_3_1690/chi_c0/omega_782, whose dynamics were never floated in the original fit either
# (so their starting and converged values already coincide).
DYNAMICS_SPECS = {
    "rho0_770":    (0.770229, 0.148864, True, (0.60, 0.95), (0.05, 0.30)),
    "omega_782":   (0.78265, 0.00849, True,  None, None),
    "rho0_1450":   (1.46500, 0.40000, True,  None, None),
    "f2_1270":     (1.25071, 0.170502, True, (1.10, 1.40), (0.05, 0.35)),
    "rho0_3_1690": (1.68600, 0.18600, True,  None, None),
    "sigma0":      (0.509084, 0.425813, True, (0.30, 0.70), (0.20, 0.90)),
    "f0_980":      (0.976535, 0.047831, True, (0.85, 1.10), (0.01, 0.20)),
    "chi_c0":      (3.41471, 0.01310, True,  None, None),
    "f0_1370":     (1.50218, 0.173547, True, (1.10, 1.80), (0.05, 0.60)),
}

SPINS = {
    "rho0_770": 1, "omega_782": 1, "rho0_1450": 1, "f2_1270": 2, "rho0_3_1690": 3,
    "sigma0": 0, "f0_980": 0, "chi_c0": 0, "f0_1370": 0,
}

LINESHAPES = {
    "rho0_770": GounarisSakurai, "omega_782": RelativisticBreitWigner,
    "rho0_1450": GounarisSakurai, "f2_1270": RelativisticBreitWigner,
    "rho0_3_1690": RelativisticBreitWigner, "sigma0": SigmaPole,
    "f0_980": RelativisticBreitWigner, "chi_c0": RelativisticBreitWigner,
    "f0_1370": RelativisticBreitWigner,
}


def make_shared_coefficients():
    coefficients = {}
    for name, (x0, y0, dx0, dy0, fx, fy, fdx, fdy) in COEFFICIENT_SPECS.items():
        x = Parameter.coefficient(f"{name}.x", x0, owner=name, fixed=fx)
        y = Parameter.coefficient(f"{name}.y", y0, owner=name, fixed=fy)
        dx = Parameter.coefficient(f"{name}.dx", dx0, owner=name, fixed=fdx)
        dy = Parameter.coefficient(f"{name}.dy", dy0, owner=name, fixed=fdy)
        coefficients[name] = CPRealImag(x, y, dx, dy)
    return coefficients


def make_dynamics_parameters():
    dynamics = {}
    for name, (mass0, width0, fixed, mass_bounds, width_bounds) in DYNAMICS_SPECS.items():
        dynamics[f"{name}.mass"] = Parameter.dynamics(
            f"{name}.mass", mass0, owner=name, fixed=fixed,
            bounds=None if fixed else mass_bounds,
        )
        dynamics[f"{name}.width"] = Parameter.dynamics(
            f"{name}.width", width0, owner=name, fixed=fixed,
            bounds=None if fixed else width_bounds,
        )
    return dynamics


shared_coefficients = make_shared_coefficients()
dynamics_parameters = make_dynamics_parameters()

TRUE_VALUES = {}
for _name, (_x0, _y0, _dx0, _dy0, *_rest) in COEFFICIENT_SPECS.items():
    TRUE_VALUES[f"{_name}.x"], TRUE_VALUES[f"{_name}.y"] = _x0, _y0
    TRUE_VALUES[f"{_name}.dx"], TRUE_VALUES[f"{_name}.dy"] = _dx0, _dy0
for _name, (_mass0, _width0, *_rest) in DYNAMICS_SPECS.items():
    TRUE_VALUES[f"{_name}.mass"], TRUE_VALUES[f"{_name}.width"] = _mass0, _width0

# %% [markdown]
# ## Componentes da amplitude
#
# Idêntico ao notebook 22 -- `pair=(2, 0)`, `angular=ZemachP()`, raios de barreira 4.0 GeV⁻¹ fixos.
# `plus_model`/`minus_model` são construídos uma única vez; só a amostra de dados varia por toy.

# %%
def build_components(charge, shared, dynamics):
    coefficient = {name: cp.for_charge(charge) for name, cp in shared.items()}
    return [
        Resonance(
            name, RESONANCE_PAIR, coefficient[name],
            lineshape=LINESHAPES[name](), angular=ZemachP(),
            mass=dynamics[f"{name}.mass"], width=dynamics[f"{name}.width"], spin=SPINS[name],
            resonance_radius=4.0, parent_radius=4.0,
        )
        for name in COEFFICIENT_SPECS
    ]


plus_model = DecayModel(
    PLUS_CHANNEL, build_components(+1, shared_coefficients, dynamics_parameters),
    normalize_components=True,
    **NORMALIZATION_CONFIG
)
minus_model = DecayModel(
    MINUS_CHANNEL, build_components(-1, shared_coefficients, dynamics_parameters),
    normalize_components=True,
    **NORMALIZATION_CONFIG
)

print("B+ components:", [c.name for c in plus_model.amplitude_model.components])
print("B+ normalization sample size:", plus_model.normalization_sample.size)
# Out:
# B+ components: ['rho0_770', 'omega_782', 'rho0_1450', 'f2_1270', 'rho0_3_1690', 'sigma0', 'f0_980', 'chi_c0', 'f0_1370']
# INFO DalitzPlotFitter normalization: narrow resonance band(s) detected, but none is aligned with the selected Square-Dalitz mass pair; keeping the standard 500 x 500 grid.
# B+ normalization sample size: 250000

# %% [markdown]
# ## Assimetria de yield dos backgrounds
#
# Idêntico ao notebook 22: `with_charge_asymmetry` normaliza cada forma pela sua própria integral
# pós-veto na amostra de normalização de `plus_model`/`minus_model` (fixa, não depende do toy) e
# escala por `(1 ∓ asym)`.

# %%
qqbar_plus_shape = _qqbar_plus_pdf.with_charge_asymmetry(
    plus_model.normalization_sample, veto=D0_VETO,
    asymmetry=QQBAR_YIELD_ASYMMETRY, charge=+1)
qqbar_minus_shape = _qqbar_minus_pdf.with_charge_asymmetry(
    minus_model.normalization_sample, veto=D0_VETO,
    asymmetry=QQBAR_YIELD_ASYMMETRY, charge=-1)
kpipibkg_plus_shape = _kpipibkg_pdf.with_charge_asymmetry(
    plus_model.normalization_sample, veto=D0_VETO,
    asymmetry=KPIPIBKG_YIELD_ASYMMETRY, charge=+1)
kpipibkg_minus_shape = _kpipibkg_pdf.with_charge_asymmetry(
    minus_model.normalization_sample, veto=D0_VETO,
    asymmetry=KPIPIBKG_YIELD_ASYMMETRY, charge=-1)
# Out:
# INFO DalitzPlotFitter normalization: narrow resonance band(s) detected, but none is aligned with the selected Square-Dalitz mass pair; keeping the standard 500 x 500 grid.

# %% [markdown]
# ## Laço de ajuste sobre os 500 toys
#
# Cada iteração constrói um `CPFitSession` novo (reaproveitando `plus_model`/`minus_model`/
# eficiência/background/veto já construídos acima) só com os dados daquele `iExpt`, ajusta com a
# mesma configuração do notebook 22 (`strategy=1`, HESSE, `hessian="jax"`) e grava uma linha em
# `TOY_RESULTS_CSV`. `iExpt` já presentes no CSV são pulados, então a célula é segura de re-executar
# (retoma de onde parou) e pode ser interrompida a qualquer momento sem perder os toys já ajustados.

# %%
def build_toy_fit_session(iexpt):
    samples = load_toy_samples(iexpt)
    plus_data, n_dropped_plus = drop_zero_efficiency_events(samples[+1], plus_efficiency)
    minus_data, n_dropped_minus = drop_zero_efficiency_events(samples[-1], minus_efficiency)

    session = CPFitSession(
        plus_model, minus_model,
        plus_data, minus_data,
        extended=True,
        signal_yield=Parameter("n_signal", N_SIGNAL, fixed=True),
    )
    session = session.with_efficiency(plus_efficiency, minus_efficiency)
    session = session.with_veto(D0_VETO)
    session = session.with_background(
        "qqbar", qqbar_plus_shape, minus_shape=qqbar_minus_shape,
        yield_=Parameter("n_qqbar", N_QQBAR, fixed=True),
    )
    session = session.with_background(
        "kpipibkg", kpipibkg_plus_shape, minus_shape=kpipibkg_minus_shape,
        yield_=Parameter("n_kpipibkg", N_KPIPIBKG, fixed=True),
    )
    return session, n_dropped_plus, n_dropped_minus


_template_session, _, _ = build_toy_fit_session(0)
FREE_PARAMETER_NAMES = [p.name for p in _template_session.parameters if not p.fixed and p.name in TRUE_VALUES]
print(f"free parameters tracked for the pull study: {len(FREE_PARAMETER_NAMES)}")


def run_toy(iexpt):
    session, n_dropped_plus, n_dropped_minus = build_toy_fit_session(iexpt)
    fit_t0 = time.time()
    result = session.fit(strategy=1, verbose=0, hesse=True, hessian="jax", hessian_batch_size=10)
    fit_time = time.time() - fit_t0
    values = session.result_values(result)
    row = {
        "iExpt": iexpt,
        "valid": bool(result.valid),
        "nll": float(result.fval),
        "n_plus": session.plus_data.size,
        "n_minus": session.minus_data.size,
        "n_dropped_zero_eff_plus": n_dropped_plus,
        "n_dropped_zero_eff_minus": n_dropped_minus,
        "fit_time_s": fit_time,
    }
    for name in FREE_PARAMETER_NAMES:
        row[name] = values[name]
        row[f"{name}_error"] = float(result.errors[name])
    return row


_RESULT_COLUMNS = [
    "iExpt",
    "valid",
    "nll",
    "n_plus",
    "n_minus",
    "n_dropped_zero_eff_plus",
    "n_dropped_zero_eff_minus",
    "fit_time_s",
] + [
    item
    for name in FREE_PARAMETER_NAMES
    for item in (name, f"{name}_error")
]
_LEGACY_RESULT_COLUMNS = [
    column for column in _RESULT_COLUMNS if column != "fit_time_s"
]


def _read_toy_results():
    """Read both the original and fit-time-extended CSV schemas."""
    if not TOY_RESULTS_CSV.exists():
        return pd.DataFrame(columns=_RESULT_COLUMNS)

    with TOY_RESULTS_CSV.open(newline="") as csv_file:
        rows = list(csv.reader(csv_file))
    if not rows:
        return pd.DataFrame(columns=_RESULT_COLUMNS)

    header = rows[0]
    if header not in (_RESULT_COLUMNS, _LEGACY_RESULT_COLUMNS):
        raise ValueError(
            f"Unexpected toy-results header in {TOY_RESULTS_CSV}: {header}"
        )

    normalized_rows = []
    malformed = []
    for line_number, row in enumerate(rows[1:], start=2):
        if len(row) == len(_LEGACY_RESULT_COLUMNS):
            row = row[:7] + [""] + row[7:]
        if len(row) != len(_RESULT_COLUMNS):
            malformed.append((line_number, len(row)))
            continue
        normalized_rows.append(row)
    if malformed:
        raise ValueError(
            f"Malformed toy-results rows in {TOY_RESULTS_CSV}: {malformed[:5]}"
        )
    return pd.DataFrame(normalized_rows, columns=_RESULT_COLUMNS)


def _load_completed_indices():
    if not TOY_RESULTS_CSV.exists():
        return set()
    return set(pd.read_csv(TOY_RESULTS_CSV)["iExpt"].astype(int))


_completed = _load_completed_indices()
_pending = [i for i in TOY_INDICES if i not in _completed]
print(f"{len(_completed)} toys already fitted, {len(_pending)} pending")

_header_needed = not TOY_RESULTS_CSV.exists()
for iexpt in _pending:
    try:
        row = run_toy(iexpt)
    except Exception as exc:  # keep the loop alive across a single bad toy
        print(f"iExpt={iexpt}: FAILED ({exc})")
        continue
    pd.DataFrame([row]).to_csv(TOY_RESULTS_CSV, mode="a", header=_header_needed, index=False)
    _header_needed = False
    print(f"iExpt={iexpt}: valid={row['valid']} nll={row['nll']:.2f} "
          f"(session.fit() {row['fit_time_s']:.1f}s, dropped {row['n_dropped_zero_eff_plus']}+"
          f"{row['n_dropped_zero_eff_minus']} zero-efficiency events)")
# Out:
# free parameters tracked for the pull study: 33
# 233 toys already fitted, 267 pending
# iExpt=233: valid=True nll=-496866.81 (session.fit() 30.9s, dropped 7+5 zero-efficiency events)
# iExpt=234: valid=True nll=-494019.06 (session.fit() 17.8s, dropped 1+7 zero-efficiency events)
# iExpt=235: valid=True nll=-496293.23 (session.fit() 14.8s, dropped 0+1 zero-efficiency events)
# iExpt=236: valid=True nll=-495481.34 (session.fit() 16.9s, dropped 2+4 zero-efficiency events)
# iExpt=237: valid=True nll=-492399.37 (session.fit() 21.0s, dropped 6+0 zero-efficiency events)
# iExpt=238: valid=True nll=-492050.85 (session.fit() 18.1s, dropped 2+3 zero-efficiency events)
# iExpt=239: valid=True nll=-496950.34 (session.fit() 18.1s, dropped 6+3 zero-efficiency events)
# iExpt=240: valid=True nll=-497093.36 (session.fit() 18.8s, dropped 6+5 zero-efficiency events)
# iExpt=241: valid=True nll=-494487.65 (session.fit() 19.6s, dropped 3+3 zero-efficiency events)
# iExpt=242: valid=True nll=-494687.85 (session.fit() 20.8s, dropped 6+4 zero-efficiency events)
# iExpt=243: valid=True nll=-493374.11 (session.fit() 18.0s, dropped 4+6 zero-efficiency events)
# iExpt=244: valid=True nll=-496164.72 (session.fit() 20.6s, dropped 3+4 zero-efficiency events)
# iExpt=245: valid=True nll=-494525.29 (session.fit() 18.0s, dropped 1+2 zero-efficiency events)
# iExpt=246: valid=True nll=-495113.96 (session.fit() 14.9s, dropped 0+3 zero-efficiency events)
# iExpt=247: valid=True nll=-494250.30 (session.fit() 21.7s, dropped 7+2 zero-efficiency events)
# iExpt=248: valid=True nll=-492664.79 (session.fit() 22.1s, dropped 6+8 zero-efficiency events)
# iExpt=249: valid=True nll=-496336.27 (session.fit() 18.4s, dropped 4+6 zero-efficiency events)
# iExpt=250: valid=True nll=-491743.17 (session.fit() 18.1s, dropped 5+4 zero-efficiency events)
# iExpt=251: valid=True nll=-494941.20 (session.fit() 16.5s, dropped 2+2 zero-efficiency events)
# iExpt=252: valid=True nll=-496564.07 (session.fit() 17.1s, dropped 6+6 zero-efficiency events)
# iExpt=253: valid=True nll=-492153.48 (session.fit() 19.7s, dropped 3+5 zero-efficiency events)
# iExpt=254: valid=True nll=-493339.11 (session.fit() 21.2s, dropped 8+1 zero-efficiency events)
# iExpt=255: valid=True nll=-493986.70 (session.fit() 11.3s, dropped 7+6 zero-efficiency events)
# iExpt=256: valid=True nll=-492356.31 (session.fit() 18.8s, dropped 7+6 zero-efficiency events)
# iExpt=257: valid=True nll=-494941.43 (session.fit() 21.7s, dropped 3+1 zero-efficiency events)
# iExpt=258: valid=True nll=-493210.89 (session.fit() 19.4s, dropped 6+2 zero-efficiency events)
# iExpt=259: valid=True nll=-495201.85 (session.fit() 19.2s, dropped 4+3 zero-efficiency events)
# iExpt=260: valid=True nll=-493181.53 (session.fit() 18.8s, dropped 7+5 zero-efficiency events)
# iExpt=261: valid=True nll=-494454.09 (session.fit() 20.8s, dropped 4+3 zero-efficiency events)
# iExpt=262: valid=True nll=-492237.71 (session.fit() 15.8s, dropped 1+0 zero-efficiency events)
# iExpt=263: valid=True nll=-491710.86 (session.fit() 11.6s, dropped 6+2 zero-efficiency events)
# iExpt=264: valid=True nll=-497415.50 (session.fit() 23.7s, dropped 4+2 zero-efficiency events)
# iExpt=265: valid=True nll=-497789.46 (session.fit() 19.9s, dropped 3+4 zero-efficiency events)
# iExpt=266: valid=True nll=-496311.46 (session.fit() 20.0s, dropped 2+2 zero-efficiency events)
# iExpt=267: valid=True nll=-495164.02 (session.fit() 20.9s, dropped 5+3 zero-efficiency events)
# iExpt=268: valid=True nll=-497363.00 (session.fit() 20.9s, dropped 4+6 zero-efficiency events)
# iExpt=269: valid=True nll=-497934.05 (session.fit() 24.2s, dropped 3+3 zero-efficiency events)
# iExpt=270: valid=True nll=-493399.17 (session.fit() 20.5s, dropped 2+3 zero-efficiency events)
# iExpt=271: valid=True nll=-493176.95 (session.fit() 21.1s, dropped 6+3 zero-efficiency events)
# iExpt=272: valid=True nll=-495959.04 (session.fit() 20.1s, dropped 5+5 zero-efficiency events)
# iExpt=273: valid=True nll=-494792.43 (session.fit() 21.1s, dropped 6+6 zero-efficiency events)
# iExpt=274: valid=True nll=-492579.15 (session.fit() 18.5s, dropped 6+6 zero-efficiency events)
# iExpt=275: valid=True nll=-495347.83 (session.fit() 23.7s, dropped 2+1 zero-efficiency events)
# iExpt=276: valid=True nll=-495528.55 (session.fit() 21.3s, dropped 5+4 zero-efficiency events)
# iExpt=277: valid=True nll=-495064.49 (session.fit() 22.3s, dropped 4+1 zero-efficiency events)
# iExpt=278: valid=True nll=-493632.54 (session.fit() 24.0s, dropped 5+1 zero-efficiency events)
# iExpt=279: valid=True nll=-496222.96 (session.fit() 19.1s, dropped 3+5 zero-efficiency events)
# iExpt=280: valid=True nll=-494969.32 (session.fit() 18.8s, dropped 5+3 zero-efficiency events)
# iExpt=281: valid=True nll=-493631.59 (session.fit() 19.2s, dropped 5+4 zero-efficiency events)
# iExpt=282: valid=True nll=-496213.18 (session.fit() 18.3s, dropped 4+1 zero-efficiency events)
# iExpt=283: valid=True nll=-494485.63 (session.fit() 23.8s, dropped 4+4 zero-efficiency events)
# iExpt=284: valid=True nll=-494203.80 (session.fit() 19.4s, dropped 6+2 zero-efficiency events)
# iExpt=285: valid=True nll=-493821.33 (session.fit() 27.6s, dropped 1+4 zero-efficiency events)
# iExpt=286: valid=True nll=-492062.32 (session.fit() 22.7s, dropped 1+2 zero-efficiency events)
# iExpt=287: valid=True nll=-497085.71 (session.fit() 19.7s, dropped 2+7 zero-efficiency events)
# iExpt=288: valid=True nll=-497257.25 (session.fit() 19.4s, dropped 4+2 zero-efficiency events)
# iExpt=289: valid=True nll=-493051.09 (session.fit() 24.3s, dropped 5+3 zero-efficiency events)
# iExpt=290: valid=True nll=-497249.73 (session.fit() 18.5s, dropped 5+5 zero-efficiency events)
# iExpt=291: valid=True nll=-495264.59 (session.fit() 13.4s, dropped 3+4 zero-efficiency events)
# iExpt=292: valid=True nll=-493570.82 (session.fit() 19.5s, dropped 1+3 zero-efficiency events)
# iExpt=293: valid=True nll=-493223.58 (session.fit() 20.2s, dropped 4+3 zero-efficiency events)
# iExpt=294: valid=True nll=-492709.08 (session.fit() 23.0s, dropped 5+2 zero-efficiency events)
# iExpt=295: valid=True nll=-492075.07 (session.fit() 22.3s, dropped 2+5 zero-efficiency events)
# iExpt=296: valid=True nll=-494042.80 (session.fit() 18.9s, dropped 2+6 zero-efficiency events)
# iExpt=297: valid=True nll=-494838.16 (session.fit() 20.4s, dropped 1+3 zero-efficiency events)
# iExpt=298: valid=True nll=-491014.44 (session.fit() 16.4s, dropped 3+0 zero-efficiency events)
# iExpt=299: valid=True nll=-495978.47 (session.fit() 19.2s, dropped 1+5 zero-efficiency events)
# iExpt=300: valid=True nll=-498376.15 (session.fit() 23.1s, dropped 4+5 zero-efficiency events)
# iExpt=301: valid=True nll=-496396.60 (session.fit() 25.1s, dropped 10+2 zero-efficiency events)
# iExpt=302: valid=True nll=-497191.91 (session.fit() 18.7s, dropped 4+3 zero-efficiency events)
# iExpt=303: valid=True nll=-492150.91 (session.fit() 22.1s, dropped 1+4 zero-efficiency events)
# iExpt=304: valid=True nll=-494472.28 (session.fit() 24.9s, dropped 5+1 zero-efficiency events)
# iExpt=305: valid=True nll=-493838.14 (session.fit() 13.3s, dropped 4+1 zero-efficiency events)
# iExpt=306: valid=True nll=-490644.49 (session.fit() 22.2s, dropped 1+2 zero-efficiency events)
# iExpt=307: valid=True nll=-495599.71 (session.fit() 19.9s, dropped 4+1 zero-efficiency events)
# iExpt=308: valid=True nll=-495633.20 (session.fit() 22.4s, dropped 4+2 zero-efficiency events)
# iExpt=309: valid=True nll=-492137.70 (session.fit() 23.0s, dropped 2+7 zero-efficiency events)
# iExpt=310: valid=True nll=-495143.56 (session.fit() 20.6s, dropped 1+4 zero-efficiency events)
# iExpt=311: valid=True nll=-495723.05 (session.fit() 15.7s, dropped 3+7 zero-efficiency events)
# iExpt=312: valid=True nll=-494723.14 (session.fit() 23.1s, dropped 2+3 zero-efficiency events)
# iExpt=313: valid=True nll=-496084.54 (session.fit() 19.8s, dropped 1+2 zero-efficiency events)
# iExpt=314: valid=True nll=-497810.57 (session.fit() 22.6s, dropped 3+2 zero-efficiency events)
# iExpt=315: valid=True nll=-494876.37 (session.fit() 27.1s, dropped 2+4 zero-efficiency events)
# iExpt=316: valid=True nll=-495790.25 (session.fit() 20.4s, dropped 0+2 zero-efficiency events)
# iExpt=317: valid=True nll=-492524.37 (session.fit() 21.2s, dropped 6+4 zero-efficiency events)
# iExpt=318: valid=True nll=-491448.96 (session.fit() 22.9s, dropped 6+4 zero-efficiency events)
# iExpt=319: valid=True nll=-493361.29 (session.fit() 19.1s, dropped 4+3 zero-efficiency events)
# iExpt=320: valid=True nll=-493307.27 (session.fit() 18.9s, dropped 3+4 zero-efficiency events)
# iExpt=321: valid=True nll=-492913.17 (session.fit() 22.8s, dropped 4+3 zero-efficiency events)
# iExpt=322: valid=True nll=-492441.74 (session.fit() 19.8s, dropped 4+7 zero-efficiency events)
# iExpt=323: valid=True nll=-494251.32 (session.fit() 23.4s, dropped 3+5 zero-efficiency events)
# iExpt=324: valid=True nll=-492963.52 (session.fit() 20.1s, dropped 6+6 zero-efficiency events)
# iExpt=325: valid=True nll=-493196.55 (session.fit() 16.9s, dropped 5+3 zero-efficiency events)
# iExpt=326: valid=True nll=-492930.01 (session.fit() 22.7s, dropped 4+3 zero-efficiency events)
# iExpt=327: valid=True nll=-493670.50 (session.fit() 23.2s, dropped 2+1 zero-efficiency events)
# iExpt=328: valid=True nll=-495437.65 (session.fit() 13.0s, dropped 4+1 zero-efficiency events)
# iExpt=329: valid=True nll=-493869.44 (session.fit() 22.9s, dropped 3+7 zero-efficiency events)
# iExpt=330: valid=True nll=-494053.44 (session.fit() 26.8s, dropped 6+2 zero-efficiency events)
# iExpt=331: valid=True nll=-497715.43 (session.fit() 24.4s, dropped 4+4 zero-efficiency events)
# iExpt=332: valid=True nll=-497844.89 (session.fit() 22.6s, dropped 4+3 zero-efficiency events)
# iExpt=333: valid=True nll=-496049.21 (session.fit() 17.2s, dropped 6+2 zero-efficiency events)
# iExpt=334: valid=True nll=-492558.59 (session.fit() 20.0s, dropped 3+3 zero-efficiency events)
# iExpt=335: valid=True nll=-489203.55 (session.fit() 17.5s, dropped 4+0 zero-efficiency events)
# iExpt=336: valid=True nll=-493860.61 (session.fit() 23.3s, dropped 6+3 zero-efficiency events)
# iExpt=337: valid=True nll=-494604.96 (session.fit() 19.2s, dropped 2+4 zero-efficiency events)
# iExpt=338: valid=True nll=-497448.87 (session.fit() 24.1s, dropped 4+7 zero-efficiency events)
# iExpt=339: valid=True nll=-495823.50 (session.fit() 24.1s, dropped 4+2 zero-efficiency events)
# iExpt=340: valid=True nll=-495550.38 (session.fit() 22.0s, dropped 3+7 zero-efficiency events)
# iExpt=341: valid=True nll=-499056.31 (session.fit() 21.0s, dropped 4+3 zero-efficiency events)
# iExpt=342: valid=True nll=-493103.16 (session.fit() 19.8s, dropped 8+1 zero-efficiency events)
# iExpt=343: valid=True nll=-496036.37 (session.fit() 20.7s, dropped 3+3 zero-efficiency events)
# iExpt=344: valid=True nll=-495461.47 (session.fit() 20.2s, dropped 3+4 zero-efficiency events)
# iExpt=345: valid=True nll=-496755.41 (session.fit() 14.3s, dropped 7+4 zero-efficiency events)
# iExpt=346: valid=True nll=-489771.43 (session.fit() 22.3s, dropped 4+1 zero-efficiency events)
# iExpt=347: valid=True nll=-493105.15 (session.fit() 22.7s, dropped 3+1 zero-efficiency events)
# iExpt=348: valid=True nll=-493645.20 (session.fit() 27.1s, dropped 4+3 zero-efficiency events)
# iExpt=349: valid=True nll=-494022.66 (session.fit() 20.0s, dropped 3+0 zero-efficiency events)
# iExpt=350: valid=True nll=-496473.23 (session.fit() 26.8s, dropped 6+5 zero-efficiency events)
# iExpt=351: valid=True nll=-495066.94 (session.fit() 19.5s, dropped 2+4 zero-efficiency events)
# iExpt=352: valid=True nll=-495428.02 (session.fit() 19.8s, dropped 3+1 zero-efficiency events)
# iExpt=353: valid=True nll=-495707.73 (session.fit() 21.1s, dropped 6+6 zero-efficiency events)
# iExpt=354: valid=True nll=-494595.24 (session.fit() 23.7s, dropped 5+7 zero-efficiency events)
# iExpt=355: valid=True nll=-492877.34 (session.fit() 21.5s, dropped 4+4 zero-efficiency events)
# iExpt=356: valid=True nll=-495016.58 (session.fit() 19.8s, dropped 7+3 zero-efficiency events)
# iExpt=357: valid=True nll=-494269.78 (session.fit() 22.1s, dropped 9+4 zero-efficiency events)
# iExpt=358: valid=True nll=-495301.51 (session.fit() 23.6s, dropped 3+8 zero-efficiency events)
# iExpt=359: valid=True nll=-495088.50 (session.fit() 24.0s, dropped 4+9 zero-efficiency events)
# iExpt=360: valid=True nll=-493829.60 (session.fit() 21.8s, dropped 5+1 zero-efficiency events)
# iExpt=361: valid=True nll=-495826.93 (session.fit() 20.9s, dropped 2+2 zero-efficiency events)
# iExpt=362: valid=True nll=-494610.06 (session.fit() 23.0s, dropped 3+5 zero-efficiency events)
# iExpt=363: valid=True nll=-493311.47 (session.fit() 16.1s, dropped 7+4 zero-efficiency events)
# iExpt=364: valid=True nll=-493829.84 (session.fit() 20.0s, dropped 4+1 zero-efficiency events)
# iExpt=365: valid=True nll=-492397.93 (session.fit() 13.0s, dropped 0+3 zero-efficiency events)
# iExpt=366: valid=True nll=-496784.05 (session.fit() 22.9s, dropped 5+5 zero-efficiency events)
# iExpt=367: valid=True nll=-494276.71 (session.fit() 24.4s, dropped 4+2 zero-efficiency events)
# iExpt=368: valid=True nll=-493325.72 (session.fit() 24.6s, dropped 5+6 zero-efficiency events)
# iExpt=369: valid=True nll=-493097.95 (session.fit() 28.3s, dropped 5+3 zero-efficiency events)
# iExpt=370: valid=True nll=-491657.00 (session.fit() 23.6s, dropped 5+6 zero-efficiency events)
# iExpt=371: valid=True nll=-493712.57 (session.fit() 22.8s, dropped 5+2 zero-efficiency events)
# iExpt=372: valid=True nll=-492657.72 (session.fit() 13.6s, dropped 3+2 zero-efficiency events)
# iExpt=373: valid=True nll=-498681.52 (session.fit() 20.1s, dropped 2+6 zero-efficiency events)
# iExpt=374: valid=True nll=-491615.41 (session.fit() 24.9s, dropped 3+4 zero-efficiency events)
# iExpt=375: valid=True nll=-494157.48 (session.fit() 21.3s, dropped 4+0 zero-efficiency events)
# iExpt=376: valid=True nll=-496746.70 (session.fit() 23.2s, dropped 4+1 zero-efficiency events)
# iExpt=377: valid=True nll=-492849.21 (session.fit() 21.7s, dropped 2+2 zero-efficiency events)
# iExpt=378: valid=True nll=-495799.40 (session.fit() 24.2s, dropped 5+7 zero-efficiency events)
# iExpt=379: valid=True nll=-495694.68 (session.fit() 20.8s, dropped 5+6 zero-efficiency events)
# iExpt=380: valid=True nll=-493918.03 (session.fit() 31.0s, dropped 4+2 zero-efficiency events)
# iExpt=381: valid=True nll=-495635.04 (session.fit() 17.1s, dropped 3+0 zero-efficiency events)
# iExpt=382: valid=True nll=-495074.63 (session.fit() 20.6s, dropped 3+5 zero-efficiency events)
# iExpt=383: valid=True nll=-493378.41 (session.fit() 23.7s, dropped 2+6 zero-efficiency events)
# iExpt=384: valid=True nll=-494890.23 (session.fit() 20.4s, dropped 1+1 zero-efficiency events)
# iExpt=385: valid=True nll=-493759.67 (session.fit() 21.6s, dropped 5+3 zero-efficiency events)
# iExpt=386: valid=True nll=-495209.32 (session.fit() 20.2s, dropped 4+4 zero-efficiency events)
# iExpt=387: valid=True nll=-492610.33 (session.fit() 25.3s, dropped 3+6 zero-efficiency events)
# iExpt=388: valid=True nll=-494466.53 (session.fit() 24.4s, dropped 4+4 zero-efficiency events)
# iExpt=389: valid=True nll=-496682.35 (session.fit() 24.1s, dropped 4+4 zero-efficiency events)
# iExpt=390: valid=True nll=-495315.53 (session.fit() 20.7s, dropped 3+4 zero-efficiency events)
# iExpt=391: valid=True nll=-494007.19 (session.fit() 20.4s, dropped 1+5 zero-efficiency events)
# iExpt=392: valid=True nll=-495746.68 (session.fit() 27.7s, dropped 7+6 zero-efficiency events)
# iExpt=393: valid=True nll=-494692.76 (session.fit() 23.5s, dropped 3+4 zero-efficiency events)
# iExpt=394: valid=True nll=-493806.46 (session.fit() 23.9s, dropped 4+5 zero-efficiency events)
# iExpt=395: valid=True nll=-492871.05 (session.fit() 28.0s, dropped 3+2 zero-efficiency events)
# iExpt=396: valid=True nll=-497345.59 (session.fit() 21.5s, dropped 6+4 zero-efficiency events)
# iExpt=397: valid=True nll=-496070.40 (session.fit() 21.2s, dropped 6+6 zero-efficiency events)
# iExpt=398: valid=True nll=-494387.47 (session.fit() 27.2s, dropped 4+8 zero-efficiency events)
# iExpt=399: valid=True nll=-493948.82 (session.fit() 22.4s, dropped 1+6 zero-efficiency events)
# iExpt=400: valid=True nll=-494787.33 (session.fit() 24.2s, dropped 5+4 zero-efficiency events)
# iExpt=401: valid=True nll=-493925.36 (session.fit() 24.4s, dropped 3+5 zero-efficiency events)
# iExpt=402: valid=True nll=-497791.24 (session.fit() 20.8s, dropped 8+7 zero-efficiency events)
# iExpt=403: valid=True nll=-495366.51 (session.fit() 20.1s, dropped 5+2 zero-efficiency events)
# iExpt=404: valid=True nll=-493330.69 (session.fit() 23.1s, dropped 4+5 zero-efficiency events)
# iExpt=405: valid=True nll=-497939.14 (session.fit() 15.7s, dropped 2+3 zero-efficiency events)
# iExpt=406: valid=True nll=-495108.59 (session.fit() 30.9s, dropped 2+8 zero-efficiency events)
# iExpt=407: valid=True nll=-493192.43 (session.fit() 20.3s, dropped 2+5 zero-efficiency events)
# iExpt=408: valid=True nll=-496570.32 (session.fit() 18.0s, dropped 4+4 zero-efficiency events)
# iExpt=409: valid=True nll=-495299.67 (session.fit() 20.4s, dropped 4+6 zero-efficiency events)
# iExpt=410: valid=True nll=-491038.60 (session.fit() 25.5s, dropped 2+4 zero-efficiency events)
# iExpt=411: valid=True nll=-495412.22 (session.fit() 26.2s, dropped 4+4 zero-efficiency events)
# iExpt=412: valid=True nll=-494521.91 (session.fit() 23.5s, dropped 2+3 zero-efficiency events)
# iExpt=413: valid=True nll=-493357.25 (session.fit() 23.8s, dropped 4+1 zero-efficiency events)
# iExpt=414: valid=True nll=-495559.08 (session.fit() 21.3s, dropped 5+4 zero-efficiency events)
# iExpt=415: valid=True nll=-495458.70 (session.fit() 23.8s, dropped 5+6 zero-efficiency events)
# iExpt=416: valid=True nll=-497774.80 (session.fit() 20.8s, dropped 4+4 zero-efficiency events)
# iExpt=417: valid=True nll=-494197.48 (session.fit() 24.9s, dropped 4+7 zero-efficiency events)
# iExpt=418: valid=True nll=-495001.30 (session.fit() 19.7s, dropped 2+3 zero-efficiency events)
# iExpt=419: valid=True nll=-493810.93 (session.fit() 30.0s, dropped 4+1 zero-efficiency events)
# iExpt=420: valid=True nll=-494631.72 (session.fit() 21.2s, dropped 4+0 zero-efficiency events)
# iExpt=421: valid=True nll=-497617.15 (session.fit() 14.1s, dropped 3+5 zero-efficiency events)
# iExpt=422: valid=True nll=-496133.91 (session.fit() 23.3s, dropped 6+3 zero-efficiency events)
# iExpt=423: valid=True nll=-494829.15 (session.fit() 24.9s, dropped 6+2 zero-efficiency events)
# iExpt=424: valid=True nll=-493519.08 (session.fit() 20.2s, dropped 5+2 zero-efficiency events)
# iExpt=425: valid=True nll=-493078.60 (session.fit() 24.2s, dropped 8+4 zero-efficiency events)
# iExpt=426: valid=True nll=-492504.83 (session.fit() 20.8s, dropped 2+5 zero-efficiency events)
# iExpt=427: valid=True nll=-494210.32 (session.fit() 21.5s, dropped 1+3 zero-efficiency events)
# iExpt=428: valid=True nll=-491900.29 (session.fit() 22.1s, dropped 3+4 zero-efficiency events)
# iExpt=429: valid=True nll=-495685.48 (session.fit() 20.8s, dropped 4+4 zero-efficiency events)
# iExpt=430: valid=True nll=-496967.60 (session.fit() 24.5s, dropped 2+3 zero-efficiency events)
# iExpt=431: valid=True nll=-493394.05 (session.fit() 23.6s, dropped 5+2 zero-efficiency events)
# iExpt=432: valid=True nll=-495094.10 (session.fit() 23.5s, dropped 3+3 zero-efficiency events)
# iExpt=433: valid=True nll=-492700.90 (session.fit() 27.7s, dropped 4+5 zero-efficiency events)
# iExpt=434: valid=True nll=-491366.60 (session.fit() 22.6s, dropped 5+4 zero-efficiency events)
# iExpt=435: valid=True nll=-493976.81 (session.fit() 20.4s, dropped 6+3 zero-efficiency events)
# iExpt=436: valid=True nll=-494621.12 (session.fit() 20.3s, dropped 4+1 zero-efficiency events)
# iExpt=437: valid=True nll=-494207.46 (session.fit() 24.7s, dropped 4+2 zero-efficiency events)
# iExpt=438: valid=True nll=-496028.42 (session.fit() 23.7s, dropped 3+7 zero-efficiency events)
# iExpt=439: valid=True nll=-491611.52 (session.fit() 20.9s, dropped 6+1 zero-efficiency events)
# iExpt=440: valid=True nll=-493381.58 (session.fit() 23.9s, dropped 7+5 zero-efficiency events)
# iExpt=441: valid=True nll=-496218.39 (session.fit() 19.8s, dropped 5+3 zero-efficiency events)
# iExpt=442: valid=True nll=-494788.54 (session.fit() 17.1s, dropped 1+2 zero-efficiency events)
# iExpt=443: valid=True nll=-492553.20 (session.fit() 20.3s, dropped 0+1 zero-efficiency events)
# iExpt=444: valid=True nll=-493615.16 (session.fit() 21.2s, dropped 2+2 zero-efficiency events)
# iExpt=445: valid=True nll=-491981.73 (session.fit() 20.6s, dropped 5+1 zero-efficiency events)
# iExpt=446: valid=True nll=-491041.97 (session.fit() 22.0s, dropped 4+1 zero-efficiency events)
# iExpt=447: valid=True nll=-494051.13 (session.fit() 20.8s, dropped 8+4 zero-efficiency events)
# iExpt=448: valid=True nll=-495124.85 (session.fit() 21.0s, dropped 6+5 zero-efficiency events)
# iExpt=449: valid=True nll=-496701.91 (session.fit() 28.4s, dropped 2+2 zero-efficiency events)
# iExpt=450: valid=True nll=-491886.96 (session.fit() 20.7s, dropped 5+4 zero-efficiency events)
# iExpt=451: valid=True nll=-490085.56 (session.fit() 18.6s, dropped 4+2 zero-efficiency events)
# iExpt=452: valid=True nll=-493369.44 (session.fit() 20.1s, dropped 4+5 zero-efficiency events)
# iExpt=453: valid=True nll=-493824.83 (session.fit() 21.8s, dropped 7+2 zero-efficiency events)
# iExpt=454: valid=True nll=-497022.62 (session.fit() 21.9s, dropped 3+2 zero-efficiency events)
# iExpt=455: valid=True nll=-492189.86 (session.fit() 20.7s, dropped 6+5 zero-efficiency events)
# iExpt=456: valid=True nll=-493408.55 (session.fit() 21.3s, dropped 3+7 zero-efficiency events)
# iExpt=457: valid=True nll=-495201.09 (session.fit() 21.4s, dropped 5+1 zero-efficiency events)
# iExpt=458: valid=True nll=-493246.94 (session.fit() 22.3s, dropped 9+6 zero-efficiency events)
# iExpt=459: valid=True nll=-492164.39 (session.fit() 20.2s, dropped 5+3 zero-efficiency events)
# iExpt=460: valid=True nll=-493524.98 (session.fit() 23.6s, dropped 3+1 zero-efficiency events)
# iExpt=461: valid=True nll=-492622.01 (session.fit() 20.9s, dropped 7+5 zero-efficiency events)
# iExpt=462: valid=True nll=-493527.01 (session.fit() 26.5s, dropped 3+3 zero-efficiency events)
# iExpt=463: valid=True nll=-493360.16 (session.fit() 19.8s, dropped 3+5 zero-efficiency events)
# iExpt=464: valid=True nll=-490527.86 (session.fit() 24.2s, dropped 2+4 zero-efficiency events)
# iExpt=465: valid=True nll=-492227.35 (session.fit() 24.4s, dropped 0+1 zero-efficiency events)
# iExpt=466: valid=True nll=-496145.60 (session.fit() 21.6s, dropped 6+3 zero-efficiency events)
# iExpt=467: valid=True nll=-491320.48 (session.fit() 21.4s, dropped 3+1 zero-efficiency events)
# iExpt=468: valid=True nll=-490453.69 (session.fit() 20.7s, dropped 2+2 zero-efficiency events)
# iExpt=469: valid=True nll=-493348.17 (session.fit() 21.2s, dropped 3+4 zero-efficiency events)
# iExpt=470: valid=True nll=-491894.55 (session.fit() 19.5s, dropped 2+0 zero-efficiency events)
# iExpt=471: valid=True nll=-495517.98 (session.fit() 25.5s, dropped 5+2 zero-efficiency events)
# iExpt=472: valid=True nll=-495408.09 (session.fit() 20.9s, dropped 3+3 zero-efficiency events)
# iExpt=473: valid=True nll=-496484.03 (session.fit() 21.0s, dropped 3+7 zero-efficiency events)
# iExpt=474: valid=True nll=-494442.54 (session.fit() 24.0s, dropped 5+3 zero-efficiency events)
# iExpt=475: valid=True nll=-496657.79 (session.fit() 23.8s, dropped 5+6 zero-efficiency events)
# iExpt=476: valid=True nll=-494896.78 (session.fit() 23.0s, dropped 4+4 zero-efficiency events)
# iExpt=477: valid=True nll=-494035.74 (session.fit() 22.4s, dropped 3+1 zero-efficiency events)
# iExpt=478: valid=True nll=-495638.97 (session.fit() 23.1s, dropped 4+6 zero-efficiency events)
# iExpt=479: valid=True nll=-494950.23 (session.fit() 23.8s, dropped 6+3 zero-efficiency events)
# iExpt=480: valid=True nll=-493764.61 (session.fit() 14.0s, dropped 4+3 zero-efficiency events)
# iExpt=481: valid=True nll=-494865.37 (session.fit() 20.0s, dropped 7+0 zero-efficiency events)
# iExpt=482: valid=True nll=-494925.98 (session.fit() 20.5s, dropped 2+6 zero-efficiency events)
# iExpt=483: valid=True nll=-494006.67 (session.fit() 20.9s, dropped 5+4 zero-efficiency events)
# iExpt=484: valid=True nll=-493173.95 (session.fit() 33.1s, dropped 3+6 zero-efficiency events)
# iExpt=485: valid=True nll=-494890.24 (session.fit() 22.1s, dropped 7+2 zero-efficiency events)
# iExpt=486: valid=True nll=-494694.95 (session.fit() 26.0s, dropped 1+5 zero-efficiency events)
# iExpt=487: valid=True nll=-492766.61 (session.fit() 24.8s, dropped 3+3 zero-efficiency events)
# iExpt=488: valid=True nll=-495245.00 (session.fit() 18.9s, dropped 6+6 zero-efficiency events)
# iExpt=489: valid=True nll=-493457.69 (session.fit() 20.2s, dropped 0+4 zero-efficiency events)
# iExpt=490: valid=True nll=-495457.00 (session.fit() 24.4s, dropped 7+5 zero-efficiency events)
# iExpt=491: valid=True nll=-497456.64 (session.fit() 20.6s, dropped 5+4 zero-efficiency events)
# iExpt=492: valid=True nll=-493426.80 (session.fit() 21.4s, dropped 3+3 zero-efficiency events)
# iExpt=493: valid=True nll=-493253.24 (session.fit() 13.6s, dropped 2+4 zero-efficiency events)
# iExpt=494: valid=True nll=-495907.21 (session.fit() 21.7s, dropped 8+2 zero-efficiency events)
# iExpt=495: valid=True nll=-497545.27 (session.fit() 24.0s, dropped 2+3 zero-efficiency events)
# iExpt=496: valid=True nll=-495262.32 (session.fit() 21.3s, dropped 5+2 zero-efficiency events)
# iExpt=497: valid=True nll=-496409.58 (session.fit() 20.1s, dropped 4+5 zero-efficiency events)
# iExpt=498: valid=True nll=-496522.50 (session.fit() 21.6s, dropped 6+4 zero-efficiency events)
# iExpt=499: valid=True nll=-492232.62 (session.fit() 21.4s, dropped 4+4 zero-efficiency events)

# %% [markdown]
# ## Resultados: histogramas de cada parâmetro
#
# `toy_results` reúne todos os toys já ajustados em `TOY_RESULTS_CSV` (inclusive de execuções
# anteriores desta célula/laço). Só toys com `valid=True` entram nas estatísticas de pull abaixo.

# %%
toy_results = pd.read_csv(TOY_RESULTS_CSV)
n_valid = int(toy_results["valid"].sum())
print(f"{len(toy_results)} toys ajustados, {n_valid} com valid=True")

toy_results_valid = toy_results[toy_results["valid"]].copy()
for name in FREE_PARAMETER_NAMES:
    toy_results_valid[f"{name}_pull"] = (
        toy_results_valid[name] - TRUE_VALUES[name]
    ) / toy_results_valid[f"{name}_error"]
# Out:
# 500 toys ajustados, 500 com valid=True

# %%
def _gaussian(x, amplitude, mu, sigma):
    return amplitude * np.exp(-0.5 * ((x - mu) / sigma) ** 2)


def fit_gaussian_histogram(data, bins):
    """Least-squares Gaussian fit to a histogram of `data` (counts, Poisson-ish weights)."""
    counts, edges = np.histogram(data, bins=bins)
    centers = 0.5 * (edges[:-1] + edges[1:])
    weights = np.sqrt(np.maximum(counts, 1))
    p0 = (counts.max(), data.mean(), data.std(ddof=1))
    popt, pcov = curve_fit(_gaussian, centers, counts, p0=p0, sigma=weights, absolute_sigma=True, maxfev=10000)
    errors = np.sqrt(np.diag(pcov))
    return {
        "amplitude": popt[0], "mu": popt[1], "sigma": abs(popt[2]),
        "mu_error": errors[1], "sigma_error": errors[2],
    }, edges


GAUSSIAN_FITS = {}

fig, axes = plt.subplots(len(FREE_PARAMETER_NAMES), 3, figsize=(15.5, 3.1 * len(FREE_PARAMETER_NAMES)), constrained_layout=True)

for row, name in enumerate(FREE_PARAMETER_NAMES):
    values = toy_results_valid[name].to_numpy()
    errors_ = toy_results_valid[f"{name}_error"].to_numpy()
    pulls = toy_results_valid[f"{name}_pull"].to_numpy()
    true_value = TRUE_VALUES[name]

    value_fit, value_edges = fit_gaussian_histogram(values, bins=30)
    error_fit, error_edges = fit_gaussian_histogram(errors_, bins=30)
    pull_fit, pull_edges = fit_gaussian_histogram(pulls, bins=np.linspace(-5, 5, 31))
    GAUSSIAN_FITS[name] = {"value": value_fit, "error": error_fit, "pull": pull_fit}

    ax_val, ax_err, ax_pull = axes[row]
    ax_val.hist(values, bins=value_edges, color="#4C72B0", edgecolor="white")
    x_val = np.linspace(value_edges[0], value_edges[-1], 300)
    ax_val.plot(x_val, _gaussian(x_val, value_fit["amplitude"], value_fit["mu"], value_fit["sigma"]), color="#DD8452")
    ax_val.axvline(true_value, color="black", linestyle="--", label="valor verdadeiro")
    ax_val.set_title(
        f"{name}  (n={len(values)})\n"
        fr"$\mu$={value_fit['mu']:.5g}$\pm${value_fit['mu_error']:.2g}  "
        fr"$\sigma$={value_fit['sigma']:.5g}$\pm${value_fit['sigma_error']:.2g}"
    )
    ax_val.set_xlabel("valor ajustado")
    if row == 0:
        ax_val.legend(fontsize=8)

    ax_err.hist(errors_, bins=error_edges, color="#8172B2", edgecolor="white")
    x_err = np.linspace(error_edges[0], error_edges[-1], 300)
    ax_err.plot(x_err, _gaussian(x_err, error_fit["amplitude"], error_fit["mu"], error_fit["sigma"]), color="#DD8452")
    ax_err.set_title(
        fr"erro HESSE: $\mu$={error_fit['mu']:.3g}$\pm${error_fit['mu_error']:.2g}  "
        fr"$\sigma$={error_fit['sigma']:.3g}$\pm${error_fit['sigma_error']:.2g}"
    )
    ax_err.set_xlabel("erro do parâmetro (HESSE)")

    ax_pull.hist(pulls, bins=pull_edges, color="#55A868", edgecolor="white")
    x_pull = np.linspace(pull_edges[0], pull_edges[-1], 300)
    ax_pull.plot(x_pull, _gaussian(x_pull, pull_fit["amplitude"], pull_fit["mu"], pull_fit["sigma"]), color="#C44E52")
    ax_pull.axvline(0.0, color="black", linestyle="--")
    ax_pull.set_title(
        fr"pull: $\mu$={pull_fit['mu']:.3f}$\pm${pull_fit['mu_error']:.3f}  "
        fr"$\sigma$={pull_fit['sigma']:.3f}$\pm${pull_fit['sigma_error']:.3f}"
    )
    ax_pull.set_xlabel("(ajustado - verdadeiro) / erro")

# %% [markdown]
# ## Resumo numérico
#
# Para cada parâmetro livre: valor verdadeiro de geração e os parâmetros do ajuste gaussiano
# (`fit_gaussian_histogram`, mínimos quadrados binado com peso Poisson `sqrt(counts)`) das três
# distribuições -- valor ajustado, erro HESSE do parâmetro e pull -- com suas incertezas
# (`mu_error`/`sigma_error`, do `pcov` do `curve_fit`). Um ajuste sem viés e com incertezas
# corretamente estimadas deve dar `pull_mu` próximo de 0 e `pull_sigma` próximo de 1; `error_sigma`
# pequeno frente a `error_mu` indica que a incerteza HESSE por toy é estável entre toys (não deveria
# variar muito, já que a maior parte da amostra é fixa entre toys).

# %%
summary_rows = []
for name in FREE_PARAMETER_NAMES:
    value_fit = GAUSSIAN_FITS[name]["value"]
    error_fit = GAUSSIAN_FITS[name]["error"]
    pull_fit = GAUSSIAN_FITS[name]["pull"]
    summary_rows.append({
        "parameter": name,
        "true_value": TRUE_VALUES[name],
        "value_mu": value_fit["mu"],
        "value_mu_error": value_fit["mu_error"],
        "value_sigma": value_fit["sigma"],
        "value_sigma_error": value_fit["sigma_error"],
        "error_mu": error_fit["mu"],
        "error_mu_error": error_fit["mu_error"],
        "error_sigma": error_fit["sigma"],
        "error_sigma_error": error_fit["sigma_error"],
        "pull_mu": pull_fit["mu"],
        "pull_mu_error": pull_fit["mu_error"],
        "pull_sigma": pull_fit["sigma"],
        "pull_sigma_error": pull_fit["sigma_error"],
    })

pull_summary = pd.DataFrame(summary_rows).set_index("parameter")
pull_summary
# Out:
#                 true_value  value_mu  value_mu_error  value_sigma  \
# parameter
# rho0_770.dx       0.001023  0.001226        0.000177     0.003676
# omega_782.x      -0.030327 -0.030418        0.000178     0.003859
# omega_782.y       0.094885  0.094848        0.000158     0.003293
# omega_782.dx      0.007299  0.006761        0.000183     0.003883
# omega_782.dy      0.013826  0.013777        0.000160     0.003431
# rho0_1450.x      -0.270865 -0.270494        0.000263     0.005559
# rho0_1450.y       0.113529  0.114324        0.000229     0.004722
# rho0_1450.dx     -0.091649 -0.091401        0.000281     0.006096
# rho0_1450.dy     -0.007719 -0.007533        0.000227     0.004926
# f2_1270.x         0.351291  0.351708        0.000195     0.004156
# f2_1270.y         0.171931  0.171940        0.000213     0.004442
# f2_1270.dx       -0.054589 -0.055318        0.000195     0.004193
# f2_1270.dy       -0.117944 -0.118138        0.000252     0.005207
# rho0_3_1690.x     0.096499  0.096345        0.000180     0.003859
# rho0_3_1690.y     0.019197  0.019137        0.000259     0.005402
# rho0_3_1690.dx    0.049237  0.049317        0.000211     0.004246
# rho0_3_1690.dy    0.054142  0.054366        0.000225     0.004834
# sigma0.x         -0.402003 -0.401586        0.000239     0.004982
# sigma0.y          0.357099  0.357531        0.000225     0.004670
# sigma0.dx         0.286690  0.286772        0.000213     0.004540
# sigma0.dy         0.201322  0.201200        0.000216     0.004498
# f0_980.x          0.141060  0.141543        0.000180     0.003824
# f0_980.y         -0.014050 -0.014069        0.000153     0.003237
# f0_980.dx        -0.045093 -0.044758        0.000182     0.003819
# f0_980.dy        -0.077090 -0.077299        0.000151     0.003269
# chi_c0.x          0.027143  0.026740        0.000164     0.003497
# chi_c0.y          0.014173  0.014787        0.000195     0.004152
# chi_c0.dx        -0.040204 -0.039911        0.000162     0.003486
# chi_c0.dy        -0.040267 -0.040238        0.000194     0.004133
# f0_1370.x         0.100608  0.101234        0.000222     0.004543
# f0_1370.y        -0.023474 -0.022825        0.000189     0.003968
# f0_1370.dx        0.051170  0.051014        0.000196     0.004233
# f0_1370.dy       -0.056314 -0.056421        0.000181     0.003923
#
#                 value_sigma_error  error_mu  error_mu_error  error_sigma  \
# parameter
# rho0_770.dx              0.000133  0.003557    7.129961e-07     0.000015
# omega_782.x              0.000136  0.004111    1.439603e-06     0.000030
# omega_782.y              0.000126  0.003598    1.412029e-06     0.000030
# omega_782.dx             0.000136  0.004168    1.446057e-06     0.000030
# omega_782.dy             0.000118  0.003562    1.476522e-06     0.000031
# rho0_1450.x              0.000191  0.006251    4.605569e-06     0.000096
# rho0_1450.y              0.000183  0.005252    2.682507e-06     0.000058
# rho0_1450.dx             0.000218  0.006305    4.477287e-06     0.000094
# rho0_1450.dy             0.000170  0.005107    2.758747e-06     0.000060
# f2_1270.x                0.000146  0.004600    1.746653e-06     0.000038
# f2_1270.y                0.000169  0.004946    2.219343e-06     0.000047
# f2_1270.dx               0.000148  0.004436    1.773014e-06     0.000038
# f2_1270.dy               0.000194  0.004975    2.297794e-06     0.000048
# rho0_3_1690.x            0.000144  0.003922    2.587782e-06     0.000054
# rho0_3_1690.y            0.000217  0.005021    4.217268e-06     0.000088
# rho0_3_1690.dx           0.000174  0.003887    2.592557e-06     0.000054
# rho0_3_1690.dy           0.000168  0.005012    4.110851e-06     0.000086
# sigma0.x                 0.000190  0.005095    1.770379e-06     0.000037
# sigma0.y                 0.000167  0.004760    1.429579e-06     0.000030
# sigma0.dx                0.000168  0.004994    2.262097e-06     0.000049
# sigma0.dy                0.000159  0.004674    1.379730e-06     0.000029
# f0_980.x                 0.000137  0.003801    2.221482e-06     0.000046
# f0_980.y                 0.000125  0.003525    1.441841e-06     0.000031
# f0_980.dx                0.000132  0.003748    2.113912e-06     0.000044
# f0_980.dy                0.000112  0.003552    1.444554e-06     0.000031
# chi_c0.x                 0.000123  0.003654    1.487144e-05     0.000300
# chi_c0.y                 0.000144  0.004227    1.035626e-05     0.000220
# chi_c0.dx                0.000128  0.003654    1.486840e-05     0.000299
# chi_c0.dy                0.000150  0.004230    1.036820e-05     0.000220
# f0_1370.x                0.000180  0.004457    3.369006e-06     0.000071
# f0_1370.y                0.000146  0.004078    2.322414e-06     0.000048
# f0_1370.dx               0.000147  0.004445    3.370170e-06     0.000071
# f0_1370.dy               0.000145  0.004103    2.422295e-06     0.000050
#
#                 error_sigma_error   pull_mu  pull_mu_error  pull_sigma  \
# parameter
# rho0_770.dx          5.178570e-07  0.050451       0.048174    1.025431
# omega_782.x          1.144400e-06 -0.000386       0.043289    0.948606
# omega_782.y          1.097764e-06  0.003973       0.043964    0.958091
# omega_782.dx         1.112380e-06 -0.143107       0.043005    0.949817
# omega_782.dy         1.116322e-06 -0.054931       0.044008    0.958216
# rho0_1450.x          3.737859e-06  0.052243       0.041877    0.914307
# rho0_1450.y          2.060783e-06  0.148098       0.043521    0.937498
# rho0_1450.dx         3.418923e-06  0.051369       0.043883    0.961667
# rho0_1450.dy         2.132093e-06  0.023009       0.043860    0.964295
# f2_1270.x            1.330992e-06  0.104607       0.040779    0.890077
# f2_1270.y            1.593739e-06  0.015435       0.042453    0.915408
# f2_1270.dx           1.354608e-06 -0.123294       0.045982    1.004121
# f2_1270.dy           1.691621e-06  0.000765       0.047951    1.026461
# rho0_3_1690.x        1.924421e-06 -0.043705       0.045486    0.990648
# rho0_3_1690.y        3.254554e-06  0.009560       0.048239    1.035183
# rho0_3_1690.dx       1.925047e-06 -0.031214       0.049153    1.052680
# rho0_3_1690.dy       3.145251e-06  0.076242       0.046098    1.007402
# sigma0.x             1.299422e-06  0.096179       0.046010    0.987778
# sigma0.y             1.145493e-06  0.074610       0.046588    0.976357
# sigma0.dx            1.709625e-06  0.030619       0.042664    0.928687
# sigma0.dy            1.142787e-06 -0.025834       0.044877    0.963644
# f0_980.x             1.670741e-06  0.122566       0.045810    0.993730
# f0_980.y             1.100894e-06 -0.001193       0.042091    0.918754
# f0_980.dx            1.570474e-06  0.036452       0.047418    1.032634
# f0_980.dy            1.093728e-06 -0.058104       0.041398    0.902674
# chi_c0.x             1.352753e-05 -0.115184       0.045856    0.998432
# chi_c0.y             8.366735e-06  0.151649       0.046739    1.014427
# chi_c0.dx            1.350015e-05  0.042078       0.043065    0.938973
# chi_c0.dy            8.374611e-06 -0.001980       0.044107    0.960351
# f0_1370.x            2.394579e-06  0.118662       0.048054    1.020782
# f0_1370.y            1.852651e-06  0.168293       0.044361    0.970073
# f0_1370.dx           2.400260e-06 -0.025331       0.044625    0.983318
# f0_1370.dy           1.989964e-06 -0.033208       0.044439    0.968534
#
#                 pull_sigma_error
# parameter
# rho0_770.dx             0.033839
# omega_782.x             0.032967
# omega_782.y             0.034216
# omega_782.dx            0.030823
# omega_782.dy            0.031879
# rho0_1450.x             0.029658
# rho0_1450.y             0.033230
# rho0_1450.dx            0.032912
# rho0_1450.dy            0.031961
# f2_1270.x               0.029029
# f2_1270.y               0.031729
# f2_1270.dx              0.034793
# f2_1270.dy              0.034510
# rho0_3_1690.x           0.035479
# rho0_3_1690.y           0.034918
# rho0_3_1690.dx          0.035391
# rho0_3_1690.dy          0.033461
# sigma0.x                0.033217
# sigma0.y                0.033202
# sigma0.dx               0.031760
# sigma0.dy               0.031490
# f0_980.x                0.033660
# f0_980.y                0.031743
# f0_980.dx               0.032801
# f0_980.dy               0.029709
# chi_c0.x                0.033664
# chi_c0.y                0.034392
# chi_c0.dx               0.031604
# chi_c0.dy               0.032396
# f0_1370.x               0.035455
# f0_1370.y               0.031336
# f0_1370.dx              0.032592
# f0_1370.dy              0.034909
