# %% [markdown]
# # 64. Feature reference index: which notebook when
#
# **Objectives:** find the right feature-reference lesson (tutorials 15-63) for a specific
# `dalitzplotfitter` class or function, without re-reading the whole course.
#
# This index complements the progressive course (lessons 1-14, see
# [TUTORIALS.md](TUTORIALS.md)) with a decision table for the fitter's remaining public API.
# Each entry names the primary class/function it demonstrates and links straight to the notebook.
# Grouped the same way as `docs/catalog.md`, the canonical map of the full public API.

# %%
from pathlib import Path

notebooks = sorted(Path(".").glob("tutorial_[1-6][0-9]_*.ipynb"))
present = {p.name for p in notebooks}
print(f"{len(present)} feature-reference notebooks found in this directory.")
# Out:
# 53 feature-reference notebooks found in this directory.

# %% [markdown]
# ## One-dimensional resonance dynamics (lineshapes)
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_15_pole.ipynb](tutorial_15_pole.ipynb) | `Pole` -- simple fixed-width Breit-Wigner pole |
# | [tutorial_16_sigma_pole.ipynb](tutorial_16_sigma_pole.ipynb) | `SigmaPole` -- LHCb f0(500) pole convention |
# | [tutorial_17_gounaris_sakurai.ipynb](tutorial_17_gounaris_sakurai.ipynb) | `GounarisSakurai` -- spin-1 rho-like lineshape |
# | [tutorial_18_rho_omega_mixing.ipynb](tutorial_18_rho_omega_mixing.ipynb) | `RhoOmegaMixing` -- coherent rho-omega mixing |
# | [tutorial_19_pipi_kk_rescattering.ipynb](tutorial_19_pipi_kk_rescattering.ipynb) | `PipiKKRescattering` -- pi-pi to K-Kbar S-wave |
# | [tutorial_20_flatte_generic.ipynb](tutorial_20_flatte_generic.ipynb) | `Flatte` -- generic two-channel coupled lineshape |
# | [tutorial_21_flatte_presets.ipynb](tutorial_21_flatte_presets.ipynb) | `Flatte.f0_980()`/`.k0star_1430_*()`/`.a0_980_*()` presets |
# | [tutorial_22_babar_flatte.ipynb](tutorial_22_babar_flatte.ipynb) | `BaBarFlatte` -- BaBar B -> K pi pi Flatte convention |
# | [tutorial_23_lass.ipynb](tutorial_23_lass.ipynb) | `LASS` -- effective-range + K0*(1430) K-pi S-wave |
# | [tutorial_24_kmatrix.ipynb](tutorial_24_kmatrix.ipynb) | `KMatrix` -- five-pole five-channel pi-pi S-wave K-matrix |
# | [tutorial_25_rescattering2.ipynb](tutorial_25_rescattering2.ipynb) | `Rescattering2` -- Laura++ two-region Chebyshev S-wave |

# %% [markdown]
# ## Angular models and normalization details
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_26_angular_models.ipynb](tutorial_26_angular_models.ipynb) | `CovariantAngular` vs `ZemachP`/`ZemachPstar` |
# | [tutorial_27_narrow_resonance_grid.ipynb](tutorial_27_narrow_resonance_grid.ipynb) | Automatic narrow-resonance grid refinement |

# %% [markdown]
# ## Model import/export
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_28_export_import_model.ipynb](tutorial_28_export_import_model.ipynb) | `export_model`/`import_model`/`model_to_spec`/`model_from_spec` |
# | [tutorial_29_export_import_cp_models.ipynb](tutorial_29_export_import_cp_models.ipynb) | `export_cp_models`/`import_cp_models` (shared-Parameter identity) |
# | [tutorial_30_model_with_fitted_values.ipynb](tutorial_30_model_with_fitted_values.ipynb) | `model_with_fitted_values`/`FitSession.fit(update_model=True)` |

# %% [markdown]
# ## Vetoes
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_31_vetoes.ipynb](tutorial_31_vetoes.ipynb) | `MassWindowVeto`/`CompositeVeto`/`FunctionalVeto` |
# | [tutorial_32_vetoed_density.ipynb](tutorial_32_vetoed_density.ipynb) | `VetoedDensity`/`vetoed_signal_pdf` |

# %% [markdown]
# ## Self-cross-feed (SCF)
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_33_scf_map_dense.ipynb](tutorial_33_scf_map_dense.ipynb) | `SquareDalitzSCFMap` (dense migration) |
# | [tutorial_34_sparse_migration.ipynb](tutorial_34_sparse_migration.ipynb) | `SparseMigration` (COO migration for large grids) |

# %% [markdown]
# ## Efficiency/background maps
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_35_histogram_maps_from_arrays.ipynb](tutorial_35_histogram_maps_from_arrays.ipynb) | `SquareDalitzHistogramEfficiency`/`Background` from arrays |
# | [tutorial_36_histogram_maps_from_root.ipynb](tutorial_36_histogram_maps_from_root.ipynb) | `histogram_efficiency_from_root`/`histogram_background_from_root` |

# %% [markdown]
# ## ROOT I/O and toy generation
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_37_root_low_level_io.ipynb](tutorial_37_root_low_level_io.ipynb) | `write_cp_phase_space_sample`/`read_root_histogram2d` |
# | [tutorial_38_toy_methods_comparison.ipynb](tutorial_38_toy_methods_comparison.ipynb) | `method=\"accept-reject\"` vs `\"inverse-transform\"` |
# | [tutorial_39_prepared_inverse_toy_generator.ipynb](tutorial_39_prepared_inverse_toy_generator.ipynb) | `prepare_inverse_toy_generator`/`PreparedInverseToyGenerator` |
# | [tutorial_40_weighted_resample.ipynb](tutorial_40_weighted_resample.ipynb) | `weighted_resample` |
# | [tutorial_41_generate_cp_toy.ipynb](tutorial_41_generate_cp_toy.ipynb) | `generate_cp_toy` |

# %% [markdown]
# ## Discriminating-variable PDFs, constraints, convolution
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_42_discriminant_pdfs.ipynb](tutorial_42_discriminant_pdfs.ipynb) | `Gaussian1D`/`Exponential1D`/`Histogram1D`/`BreitWigner1D` |
# | [tutorial_43_factorized_density_and_constraints.ipynb](tutorial_43_factorized_density_and_constraints.ipynb) | `FactorizedDensity`/`LineshapeIntensity1D`/`GaussianConstraint`/`ConstrainedNLL` |
# | [tutorial_44_convolution.ipynb](tutorial_44_convolution.ipynb) | `ConvolvedPDF1D`/`GaussianResolution1D` |

# %% [markdown]
# ## Error propagation and goodness of fit
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_45_delta_method.ipynb](tutorial_45_delta_method.ipynb) | `delta_method_jacobian`/`delta_method_covariance`/`delta_method_errors` |
# | [tutorial_46_kdtree_local_residuals.ipynb](tutorial_46_kdtree_local_residuals.ipynb) | `kdtree_local_residuals` |
# | [tutorial_47_point_to_point.ipynb](tutorial_47_point_to_point.ipynb) | `PointToPointResult`/`point_to_point_dissimilarity` |

# %% [markdown]
# ## Plotting and fit-result summaries
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_48_plotting_helpers.ipynb](tutorial_48_plotting_helpers.ipynb) | `plot_dalitz`/`plot_square_dalitz`/`binned_data`/`plot_pulls` |
# | [tutorial_49_fit_fractions.ipynb](tutorial_49_fit_fractions.ipynb) | `DecayModel.fit_fractions`/`interference_fractions` |

# %% [markdown]
# ## Minimizer options
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_50_fit_multistart.ipynb](tutorial_50_fit_multistart.ipynb) | `fit_multistart`/`MultiStartResult` |
# | [tutorial_51_nesterov_optimizer.ipynb](tutorial_51_nesterov_optimizer.ipynb) | `method=\"nesterov\"`/`NesterovResult` |
# | [tutorial_52_check_gradient.ipynb](tutorial_52_check_gradient.ipynb) | `Minimizer.check_gradient` |
# | [tutorial_53_hessian_jax.ipynb](tutorial_53_hessian_jax.ipynb) | `hessian=\"jax\"` vs `\"numerical\"` |

# %% [markdown]
# ## Square-Dalitz, CP details, configuration
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_54_square_dalitz_conversions.ipynb](tutorial_54_square_dalitz_conversions.ipynb) | `invariants_to_square_dalitz`/`square_dalitz_jacobian`/`fold_thetaprime` |
# | [tutorial_55_yield_asymmetry.ipynb](tutorial_55_yield_asymmetry.ipynb) | `YieldAsymmetry` |
# | [tutorial_56_shared_parameters.ipynb](tutorial_56_shared_parameters.ipynb) | Sharing/conflicting `Parameter` objects across components |
# | [tutorial_57_float32_experiment.ipynb](tutorial_57_float32_experiment.ipynb) | `enable_x64(False)` float32 experiment |
# | [tutorial_58_coherent_amplitude_model_manual.ipynb](tutorial_58_coherent_amplitude_model_manual.ipynb) | `CoherentAmplitudeModel`/`AmplitudeComponent`/`ConstantAmplitude` |

# %% [markdown]
# ## Low-level internals
#
# | Notebook | Demonstrates |
# |---|---|
# | [tutorial_59_prepared_cache_direct.ipynb](tutorial_59_prepared_cache_direct.ipynb) | `PreparedAmplitudeCache` used directly |
# | [tutorial_60_background_category_vs_spec.ipynb](tutorial_60_background_category_vs_spec.ipynb) | `BackgroundCategory` (low-level) vs `BackgroundSpec` (high-level) |
# | [tutorial_61_cp_background_spec_and_category.ipynb](tutorial_61_cp_background_spec_and_category.ipynb) | `CPBackgroundSpec`/`CPBackgroundCategory` |
# | [tutorial_62_resonance_internals.ipynb](tutorial_62_resonance_internals.ipynb) | `ResonanceAmplitude`/`ResonanceContext` |
# | [tutorial_63_dalitz_amplitude_qmi2d.ipynb](tutorial_63_dalitz_amplitude_qmi2d.ipynb) | `DalitzAmplitude` wrapping `QMI2D` |

# %%
expected = [
    "tutorial_15_pole.ipynb",
    "tutorial_16_sigma_pole.ipynb",
    "tutorial_17_gounaris_sakurai.ipynb",
    "tutorial_18_rho_omega_mixing.ipynb",
    "tutorial_19_pipi_kk_rescattering.ipynb",
    "tutorial_20_flatte_generic.ipynb",
    "tutorial_21_flatte_presets.ipynb",
    "tutorial_22_babar_flatte.ipynb",
    "tutorial_23_lass.ipynb",
    "tutorial_24_kmatrix.ipynb",
    "tutorial_25_rescattering2.ipynb",
    "tutorial_26_angular_models.ipynb",
    "tutorial_27_narrow_resonance_grid.ipynb",
    "tutorial_28_export_import_model.ipynb",
    "tutorial_29_export_import_cp_models.ipynb",
    "tutorial_30_model_with_fitted_values.ipynb",
    "tutorial_31_vetoes.ipynb",
    "tutorial_32_vetoed_density.ipynb",
    "tutorial_33_scf_map_dense.ipynb",
    "tutorial_34_sparse_migration.ipynb",
    "tutorial_35_histogram_maps_from_arrays.ipynb",
    "tutorial_36_histogram_maps_from_root.ipynb",
    "tutorial_37_root_low_level_io.ipynb",
    "tutorial_38_toy_methods_comparison.ipynb",
    "tutorial_39_prepared_inverse_toy_generator.ipynb",
    "tutorial_40_weighted_resample.ipynb",
    "tutorial_41_generate_cp_toy.ipynb",
    "tutorial_42_discriminant_pdfs.ipynb",
    "tutorial_43_factorized_density_and_constraints.ipynb",
    "tutorial_44_convolution.ipynb",
    "tutorial_45_delta_method.ipynb",
    "tutorial_46_kdtree_local_residuals.ipynb",
    "tutorial_47_point_to_point.ipynb",
    "tutorial_48_plotting_helpers.ipynb",
    "tutorial_49_fit_fractions.ipynb",
    "tutorial_50_fit_multistart.ipynb",
    "tutorial_51_nesterov_optimizer.ipynb",
    "tutorial_52_check_gradient.ipynb",
    "tutorial_53_hessian_jax.ipynb",
    "tutorial_54_square_dalitz_conversions.ipynb",
    "tutorial_55_yield_asymmetry.ipynb",
    "tutorial_56_shared_parameters.ipynb",
    "tutorial_57_float32_experiment.ipynb",
    "tutorial_58_coherent_amplitude_model_manual.ipynb",
    "tutorial_59_prepared_cache_direct.ipynb",
    "tutorial_60_background_category_vs_spec.ipynb",
    "tutorial_61_cp_background_spec_and_category.ipynb",
    "tutorial_62_resonance_internals.ipynb",
    "tutorial_63_dalitz_amplitude_qmi2d.ipynb"
]
missing = [f for f in expected if f not in present]
assert not missing, f"missing notebooks: {missing}"
print(f"All {len(expected)} feature-reference notebooks referenced above are present.")
# Out:
# All 49 feature-reference notebooks referenced above are present.

# %% [markdown]
# ## Continue learning
#
# - Progressive course (lessons 1-14): [TUTORIALS.md](TUTORIALS.md)
# - Full public API map: [`docs/catalog.md`](../../docs/catalog.md)
# - Per-topic docs referenced throughout this reference set live under [`docs/`](../../docs/)
